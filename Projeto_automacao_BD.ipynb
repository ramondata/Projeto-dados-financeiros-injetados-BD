# %%
import pandas as pd

# %%
excel = pd.read_excel('Carteira.xlsx',sheet_name='Renda_variavel')

# %%
excel
# Out:
#                  Setor   Ativo  Preço médio  Quantidade  Valor médio  Pregão  \
# 0     Bolsa de valores   B3SA3        14.42    130.0000  1874.600000   11.38
# 1       Financeiro etc   ITSA4        10.82    215.0000  2326.300000    8.99
# 2           Financeiro     BAC        25.91     19.7083   510.642053   44.42
# 3          Serviços TI   SQIA3        23.02     55.0000  1266.100000   16.88
# 4     Energia elétrica   EGIE3        44.08     43.0000  1895.440000   38.60
# 5              Motores   WEGE3        23.89     98.0000  2341.220000   33.47
# 6           Financeiro     JPM       100.75      6.5363   658.532225  157.26
# 7          Serviços TI    MSFT       254.34      1.8000   457.812000  334.69
# 8             Alimento   MDIA3        39.79     34.0000  1352.860000   24.82
# 9              Imóveis  BCFF11        85.80     62.0000  5319.600000   69.80
# 10               Saúde   GNDI3        58.21     15.0000   873.150000   61.45
# ...

# %%
Money = ['MSFT']
Money_in = excel['Ativo'].isin(Money)

# %%
excel[Money_in]
# Out:
#          Setor Ativo  Preço médio  Quantidade  Valor médio  Pregão  Posição  \
# 7  Serviços TI  MSFT       254.34         1.8      457.812  334.69  602.442
#
#     Lucro  Variação
# 7  144.63  0.315916

# %%
excel.dtypes
# Out:
# Setor           object
# Ativo           object
# Preço médio    float64
# Quantidade     float64
# Valor médio    float64
# Pregão         float64
# Posição        float64
# Lucro          float64
# Variação       float64
# dtype: object
