# %%
import pandas as pd

# %%
excel = pd.read_excel('Carteira.xlsx',sheet_name='Renda_variavel')

# %%
excel
# Out:
#                  Setor   Ativo  Preço médio  Quantidade  Valor médio  Pregão  \
# 0     Bolsa de valores   B3SA3        14.42         100       1442.0   11.38
# 1       Financeiro etc   ITSA4        10.82         100       1082.0    8.99
# 2           Financeiro     BAC        25.91         100       2591.0   44.42
# 3          Serviços TI   SQIA3        23.02         100       2302.0   16.88
# 4     Energia elétrica   EGIE3        44.08         100       4408.0   38.60
# 5              Motores   WEGE3        23.89         100       2389.0   33.47
# 6           Financeiro     JPM       100.75         100      10075.0  157.26
# 7          Serviços TI    MSFT       254.34         100      25434.0  334.69
# 8             Alimento   MDIA3        39.79         100       3979.0   24.82
# 9              Imóveis  BCFF11        85.80         100       8580.0   69.80
# 10               Saúde   GNDI3        58.21         100       5821.0   61.45
# ...

# %%
Money = ['MSFT']
Money_in = excel['Ativo'].isin(Money)

# %%
excel[Money_in]
# Out:
#          Setor Ativo  Preço médio  Quantidade  Valor médio  Pregão  Posição  \
# 7  Serviços TI  MSFT       254.34         100      25434.0  334.69    33469
#
#     Lucro  Variação
# 7  8035.0  0.315916

# %%
excel.dtypes
# Out:
# Setor           object
# Ativo           object
# Preço médio    float64
# Quantidade       int64
# Valor médio    float64
# Pregão         float64
# Posição          int64
# Lucro          float64
# Variação       float64
# dtype: object
